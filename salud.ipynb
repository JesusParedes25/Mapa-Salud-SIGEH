# %%
import folium
import pandas as pd
import geopandas as gpd
import json
from folium.plugins import MeasureControl
from folium.plugins import Search
from folium.plugins import LocateControl
from folium.features import CustomIcon
from folium.plugins import MarkerCluster
from folium.plugins import Draw
from folium import IFrame
from folium import plugins
import branca.colormap as cm
from folium.plugins import MiniMap

# Crea un mapa base con un centro y un nivel de zoom determinados
m = folium.Map(location=[20.5153, -98.7459], zoom_start=9, tiles="openstreetmap", min_zoom=8, control_scale=True,max_bounds=[[21.7010, -100.0662], [19.3611,  -97.1548]])
# Se agregan los mapa base
folium.TileLayer(
    tiles='stamenterrain',
    attr='',
    name='Terrreno'
).add_to(m)

folium.TileLayer(
    tiles='cartodbdark_matter',
    name='Obscuro'
).add_to(m)
tile = folium.TileLayer(
        tiles = 'https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
        attr = 'Esri',
        name = 'Esri Satellite',
        overlay = False,
        control = True
       ).add_to(m)

# Agrego capas convirtiendo los geojson en Geodataframes
psdh_gdf=gpd.read_file("psdh.geojson")
h_huasteca_gdf=gpd.read_file('h_huasteca1.geojson')
hospitales_gdf=gpd.read_file('hospitales.geojson')
salud_gdf=gpd.read_file('salud1.geojson')
clues_gdf=gpd.read_file('clues1.geojson')
#ageb_csv= pd.read_csv("ageb.csv")
# Creo un estilo 
bordersStyle = {'color': 'brown',
                'weight': 1,
                'fillColor': '#DDc9A3',
                'fillOpacity': 0,
                'opacity':0.5,
                'line_opacity': .2,
               }

icono = folium.DivIcon(
    icon_size=(100, 100),
    icon_anchor=(50, 50),
    html=f"""
        <div style="text-align:center; box-shadow: 0 0 10px rgba(0, 0, 0, 0.5); border-radius: 10px; overflow: hidden;">
            <img src="https://inabisa.com.mx/img/sigeh/derechohabiencia.png" alt="Imagen" style="width:100%">
        </div>
    """
)
icono1 = folium.DivIcon(
    icon_size=(100, 100),
    icon_anchor=(50, 50),
    html=f"""
        <div style="text-align:center; box-shadow: 0 0 10px rgba(0, 0, 0, 0.5); border-radius: 10px; overflow: hidden;">
            <img src="https://inabisa.com.mx/img/sigeh/motriz.png" alt="Imagen" style="width:100%">
        </div>
    """
)

icono2 = folium.DivIcon(
    icon_size=(100, 100),
    icon_anchor=(50, 50),
    html=f"""
        <div style="text-align:center; box-shadow: 0 0 10px rgba(0, 0, 0, 0.5); border-radius: 10px; overflow: hidden;">
            <img src="https://inabisa.com.mx/img/sigeh/mental.png" alt="Imagen" style="width:100%">
        </div>
    """
)

icono3 = folium.DivIcon(
    icon_size=(100, 100),
    icon_anchor=(50, 50),
    html=f"""
        <div style="text-align:center; box-shadow: 0 0 10px rgba(0, 0, 0, 0.5); border-radius: 10px; overflow: hidden;">
            <img src="https://inabisa.com.mx/img/sigeh/visual.png" alt="Imagen" style="width:100%">
        </div>
    """
)

icono4 = folium.DivIcon(
    icon_size=(100, 100),
    icon_anchor=(50, 50),
    html=f"""
        <div style="text-align:center; box-shadow: 0 0 10px rgba(0, 0, 0, 0.5); border-radius: 10px; overflow: hidden;">
            <img src="https://inabisa.com.mx/img/sigeh/habla.png" alt="Imagen" style="width:100%">
        </div>
    """
)

icono5 = folium.DivIcon(
    icon_size=(100, 100),
    icon_anchor=(50, 50),
    html=f"""
        <div style="text-align:center; box-shadow: 0 0 10px rgba(0, 0, 0, 0.5); border-radius: 10px; overflow: hidden;">
            <img src="https://inabisa.com.mx/img/sigeh/auditiva.png" alt="Imagen" style="width:100%">
        </div>
    """
)
icono6 = folium.DivIcon(
    icon_size=(100, 100),
    icon_anchor=(50, 50),
    html=f"""
        <div style="text-align:center; box-shadow: 0 0 10px rgba(0, 0, 0, 0.5); border-radius: 10px; overflow: hidden;">
            <img src="https://inabisa.com.mx/img/sigeh/salud6.png" alt="Imagen" style="width:100%">
        </div>
    """
)
icono7 = folium.DivIcon(
    icon_size=(100, 100),
    icon_anchor=(50, 50),
    html=f"""
        <div style="text-align:center; box-shadow: 0 0 10px rgba(0, 0, 0, 0.5); border-radius: 10px; overflow: hidden;">
            <img src="https://inabisa.com.mx/img/sigeh/salud7.png" alt="Imagen" style="width:100%">
        </div>
    """
)
icono8 = folium.DivIcon(
    icon_size=(100, 100),
    icon_anchor=(50, 50),
    html=f"""
        <div style="text-align:center; box-shadow: 0 0 10px rgba(0, 0, 0, 0.5); border-radius: 10px; overflow: hidden;">
            <img src="https://inabisa.com.mx/img/sigeh/salud8.png" alt="Imagen" style="width:100%">
        </div>
    """
)
icono9 = folium.DivIcon(
    icon_size=(100, 100),
    icon_anchor=(50, 50),
    html=f"""
        <div style="text-align:center; box-shadow: 0 0 10px rgba(0, 0, 0, 0.5); border-radius: 10px; overflow: hidden;">
            <img src="https://inabisa.com.mx/img/sigeh/salud9.png" alt="Imagen" style="width:100%">
        </div>
    """
)
icono10 = folium.DivIcon(
    icon_size=(100, 100),
    icon_anchor=(50, 50),
    html=f"""
        <div style="text-align:center; box-shadow: 0 0 10px rgba(0, 0, 0, 0.5); border-radius: 10px; overflow: hidden;">
            <img src="https://inabisa.com.mx/img/sigeh/salud10.png" alt="Imagen" style="width:100%">
        </div>
    """
)
icono11 = folium.DivIcon(
    icon_size=(100, 100),
    icon_anchor=(50, 50),
    html=f"""
        <div style="text-align:center; box-shadow: 0 0 10px rgba(0, 0, 0, 0.5); border-radius: 10px; overflow: hidden;">
            <img src="https://inabisa.com.mx/img/sigeh/salud11.png" alt="Imagen" style="width:100%">
        </div>
    """
)
icono12 = folium.DivIcon(
    icon_size=(100, 100),
    icon_anchor=(50, 50),
    html=f"""
        <div style="text-align:center; box-shadow: 0 0 10px rgba(0, 0, 0, 0.5); border-radius: 10px; overflow: hidden;">
            <img src="https://inabisa.com.mx/img/sigeh/salud12.png" alt="Imagen" style="width:100%">
        </div>
    """
)
icono13 = folium.DivIcon(
    icon_size=(100, 100),
    icon_anchor=(50, 50),
    html=f"""
        <div style="text-align:center; box-shadow: 0 0 10px rgba(0, 0, 0, 0.5); border-radius: 10px; overflow: hidden;">
            <img src="https://inabisa.com.mx/img/sigeh/salud13.png" alt="Imagen" style="width:100%">
        </div>
    """
)
icono14 = folium.DivIcon(
    icon_size=(100, 100),
    icon_anchor=(50, 50),
    html=f"""
        <div style="text-align:center; box-shadow: 0 0 10px rgba(0, 0, 0, 0.5); border-radius: 10px; overflow: hidden;">
            <img src="https://inabisa.com.mx/img/sigeh/salud14.png" alt="Imagen" style="width:100%">
        </div>
    """
)
icono15 = folium.DivIcon(
    icon_size=(100, 100),
    icon_anchor=(50, 50),
    html=f"""
        <div style="text-align:center; box-shadow: 0 0 10px rgba(0, 0, 0, 0.5); border-radius: 10px; overflow: hidden;">
            <img src="https://inabisa.com.mx/img/sigeh/salud15.png" alt="Imagen" style="width:100%">
        </div>
    """
)
icono16 = folium.DivIcon(
    icon_size=(100, 100),
    icon_anchor=(50, 50),
    html=f"""
        <div style="text-align:center; box-shadow: 0 0 10px rgba(0, 0, 0, 0.5); border-radius: 10px; overflow: hidden;">
            <img src="https://inabisa.com.mx/img/sigeh/salud16.png" alt="Imagen" style="width:100%">
        </div>
    """
)
icono17 = folium.DivIcon(
    icon_size=(100, 100),
    icon_anchor=(50, 50),
    html=f"""
        <div style="text-align:center; box-shadow: 0 0 10px rgba(0, 0, 0, 0.5); border-radius: 10px; overflow: hidden;">
            <img src="https://inabisa.com.mx/img/sigeh/salud17.png" alt="Imagen" style="width:100%">
        </div>
    """
)
icono18 = folium.DivIcon(
    icon_size=(100, 100),
    icon_anchor=(50, 50),
    html=f"""
        <div style="text-align:center; box-shadow: 0 0 10px rgba(0, 0, 0, 0.5); border-radius: 10px; overflow: hidden;">
            <img src="https://inabisa.com.mx/img/sigeh/salud18.png" alt="Imagen" style="width:100%">
        </div>
    """
)
icono19 = folium.DivIcon(
    icon_size=(100, 100),
    icon_anchor=(50, 50),
    html=f"""
        <div style="text-align:center; box-shadow: 0 0 10px rgba(0, 0, 0, 0.5); border-radius: 10px; overflow: hidden;">
            <img src="https://inabisa.com.mx/img/sigeh/salud19.png" alt="Imagen" style="width:100%">
        </div>
    """
)
psd1_leg = folium.Marker(
    location=[20.0793, -100.1677],
    icon=icono,
    draggable=True,
)
salud1_leg = folium.Marker(
    location=[20.0793, -100.1677],
    icon=icono1,
    draggable=True,
)

salud2_leg = folium.Marker(
    location=[20.0793, -100.1677],
    icon=icono2,
    draggable=True,
)
salud3_leg = folium.Marker(
    location=[20.0793, -100.1677],
    icon=icono3,
    draggable=True,
)
salud4_leg = folium.Marker(
    location=[20.0793, -100.1677],
    icon=icono4,
    draggable=True,
)
salud5_leg = folium.Marker(
    location=[20.0793, -100.1677],
    icon=icono5,
    draggable=True,
)
salud6_leg = folium.Marker(
    location=[20.0793, -100.1677],
    icon=icono6,
    draggable=True,
)
salud7_leg = folium.Marker(
    location=[20.0793, -100.1677],
    icon=icono7,
    draggable=True,
)
salud8_leg = folium.Marker(
    location=[20.0793, -100.1677],
    icon=icono8,
    draggable=True,
)
salud9_leg = folium.Marker(
    location=[20.0793, -100.1677],
    icon=icono9,
    draggable=True,
)
salud10_leg = folium.Marker(
    location=[20.0793, -100.1677],
    icon=icono10,
    draggable=True,
)
salud11_leg = folium.Marker(
    location=[20.0793, -100.1677],
    icon=icono11,
    draggable=True,
)
salud12_leg = folium.Marker(
    location=[20.0793, -100.1677],
    icon=icono12,
    draggable=True,
)
salud13_leg = folium.Marker(
    location=[20.0793, -100.1677],
    icon=icono13,
    draggable=True,
)
salud14_leg = folium.Marker(
    location=[20.0793, -100.1677],
    icon=icono14,
    draggable=True,
)
salud15_leg = folium.Marker(
    location=[20.0793, -100.1677],
    icon=icono15,
    draggable=True,
)

salud16_leg = folium.Marker(
    location=[20.0793, -100.1677],
    icon=icono16,
    draggable=True,
)

salud17_leg = folium.Marker(
    location=[20.0793, -100.1677],
    icon=icono17,
    draggable=True,
)

salud18_leg = folium.Marker(
    location=[20.0793, -100.1677],
    icon=icono18,
    draggable=True,
)

salud19_leg = folium.Marker(
    location=[20.0793, -100.1677],
    icon=icono19,
    draggable=True,
)

#Cluster de Clues
clues=folium.GeoJson(clues_gdf,
                        name='Establecimientos de Salud',
               tooltip=folium.GeoJsonTooltip(fields=["NOMBRE DE LA UNIDAD"],aliases=["Nombre: "], sticky=False, localize=True),
                       zoom_on_click=True,
                       marker=folium.Marker(icon=folium.Icon(color='blue',icon='fa-hospital-o',prefix="fa")))
mc = MarkerCluster(name='Establecimientos de Salud', show=True).add_to(m)
for _, row in clues_gdf.iterrows():
    marker = folium.Marker(location=[row['LATITUD'], row['LONGITUD']],
                           tooltip=row['NOMBRE DE LA UNIDAD'],
                           icon=folium.Icon(color='blue', icon='fa-hospital-o', prefix='fa')
                          )
    mc.add_child(marker)
    
psdh=folium.GeoJson(psdh_gdf,
               name='% Población sin derechohabiencia',
               tooltip=folium.GeoJsonTooltip(fields=["NOMGEO",'POR_PSD'],aliases=["Municipio: ", "% Población sin derechohabiencia"], sticky=False, localize=True),
               style_function=lambda x: bordersStyle,
              ).add_to(m)


psd1=folium.Choropleth(
    geo_data=psdh_gdf,
    data=psdh_gdf,
    name='% Población sin derechohabiencia',
    columns=['CVEGEO', 'POR_PSD'],
    key_on='feature.properties.CVEGEO',
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='% de Población sin derechohabiencia',
    show=True,
    control=True,
    highlight=True,
    smooth_factor=True
).add_to(m)
for child in psd1._children:
    if child.startswith("color_map"):
        del psd1._children[child]
        
psd1.get_root().add_child(psd1.color_scale)
psd1.add_child(psd1_leg)



salud1=folium.Choropleth(
    geo_data=salud_gdf,
    data=salud_gdf,
    name='% Personas con discapacidad motríz',
    columns=['CVEGEO', '% Personas con discapacidad motriz'],
    key_on='feature.properties.CVEGEO',
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='% Personas con discapacidad motríz',
    show=False,
    control=True,
    highlight=True,
    smooth_factor=True,
    toggle=True
).add_to(m)
for child in salud1._children:
    if child.startswith("color_map"):
        del salud1._children[child]
        
psd1.get_root().add_child(salud1.color_scale)
salud1.add_child(salud1_leg )


salud2=folium.Choropleth(
    geo_data=salud_gdf,
    data=salud_gdf,
    name='% Personas con alguna condición mental',
    columns=['CVEGEO', '%Personas con alguna condición mental'],
    key_on='feature.properties.CVEGEO',
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='%Personas con alguna condición mental',
    show=False,
    control=True,
    highlight=True,
    smooth_factor=True
).add_to(m)
for child in salud2._children:
    if child.startswith("color_map"):
        del salud2._children[child]
        
salud2.get_root().add_child(salud2.color_scale)
salud2.add_child(salud2_leg )

salud3=folium.Choropleth(
    geo_data=salud_gdf,
    data=salud_gdf,
    name='% Personas con discapacidad visual',
    columns=['CVEGEO', '% Personas con discapacidad visual'],
    key_on='feature.properties.CVEGEO',
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='%Personas con discapacidad visual',
    show=False,
    control=True,
    highlight=True,
    smooth_factor=True
).add_to(m)
for child in salud3._children:
    if child.startswith("color_map"):
        del salud3._children[child]
        
salud3.get_root().add_child(salud3.color_scale)
salud3.add_child(salud3_leg )

salud4=folium.Choropleth(
    geo_data=salud_gdf,
    data=salud_gdf,
    name='% Personas con discapacidad del habla',
    columns=['CVEGEO', '% Personas con discapacidad del habla'],
    key_on='feature.properties.CVEGEO',
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='% Personas con discapacidad del habla',
    show=False,
    control=True,
    highlight=True,
    smooth_factor=True
).add_to(m)
for child in salud4._children:
    if child.startswith("color_map"):
        del salud4._children[child]
        
salud4.get_root().add_child(salud4.color_scale)
salud4.add_child(salud4_leg)

salud5=folium.Choropleth(
    geo_data=salud_gdf,
    data=salud_gdf,
    name='% Personas con discapacidad auditiva',
    columns=['CVEGEO', '% Personas con discapacidad auditiva'],
    key_on='feature.properties.CVEGEO',
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='% Personas con discapacidad auditiva',
    show=False,
    control=True,
    highlight=True,
    smooth_factor=True
).add_to(m)
for child in salud5._children:
    if child.startswith("color_map"):
        del salud5._children[child]
        
salud5.get_root().add_child(salud5.color_scale)
salud5.add_child(salud5_leg)

salud6=folium.Choropleth(
    geo_data=salud_gdf,
    data=salud_gdf,
    name='Casos de COVID atendidos durante el 2022',
    columns=['CVEGEO', 'Casos de COVID atendidos durante el 2022'],
    key_on='feature.properties.CVEGEO',
    fill_color='Reds',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Casos de COVID atendidos durante el 2022',
    show=False,
    control=True,
    highlight=True,
    smooth_factor=True
).add_to(m)
for child in salud6._children:
    if child.startswith("color_map"):
        del salud6._children[child]
        
salud6.get_root().add_child(salud6.color_scale)
salud6.add_child(salud6_leg)

salud7=folium.Choropleth(
    geo_data=salud_gdf,
    data=salud_gdf,
    name='Casos activos de Dengue al 10/03/23',
    columns=['CVEGEO', 'Casos activos de Dengue al 10/03/23'],
    key_on='feature.properties.CVEGEO',
    fill_color='Reds',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Casos activos de Dengue al 10/03/23',
    show=False,
    control=True,
    highlight=True,
    smooth_factor=True
).add_to(m)
for child in salud7._children:
    if child.startswith("color_map"):
        del salud7._children[child]
        
salud7.get_root().add_child(salud7.color_scale)
salud7.add_child(salud7_leg)

salud8=folium.Choropleth(
    geo_data=salud_gdf,
    data=salud_gdf,
    name='Tasa de mortalidad infantil.',
    columns=['CVEGEO', 'tasa de mortalidad infantil'],
    key_on='feature.properties.CVEGEO',
    fill_color='BuPu',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Tasa de mortalidad infantil',
    show=False,
    control=True,
    highlight=True,
    smooth_factor=True
).add_to(m)
for child in salud8._children:
    if child.startswith("color_map"):
        del salud8._children[child]
        
salud8.get_root().add_child(salud8.color_scale)
salud8.add_child(salud8_leg)

salud9=folium.Choropleth(
    geo_data=salud_gdf,
    data=salud_gdf,
    name='Defunciones maternales 2021',
    columns=['CVEGEO', 'Defunciones maternales 2021'],
    key_on='feature.properties.CVEGEO',
    fill_color='BuPu',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Defunciones maternales 2021',
    show=False,
    control=True,
    highlight=True,
    smooth_factor=True
).add_to(m)
for child in salud9._children:
    if child.startswith("color_map"):
        del salud9._children[child]
        
salud9.get_root().add_child(salud9.color_scale)
salud9.add_child(salud9_leg)

salud10=folium.Choropleth(
    geo_data=salud_gdf,
    data=salud_gdf,
    name='Defunciones infantiles 2021',
    columns=['CVEGEO', 'defunciones infantiles 2021'],
    key_on='feature.properties.CVEGEO',
    fill_color='BuPu',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Defunciones infantiles 2021',
    show=False,
    control=True,
    highlight=True,
    smooth_factor=True
).add_to(m)
for child in salud10._children:
    if child.startswith("color_map"):
        del salud10._children[child]
        
salud10.get_root().add_child(salud10.color_scale)
salud10.add_child(salud10_leg)

salud11=folium.Choropleth(
    geo_data=salud_gdf,
    data=salud_gdf,
    name='% de población de 20 años y más con obesidad.',
    columns=['CVEGEO', 'Porcentaje de población de 20 años y más con obesidad.'],
    key_on='feature.properties.CVEGEO',
    fill_color='YlGnBu',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='% de población de 20 años y más con obesidad.',
    show=False,
    control=True,
    highlight=True,
    smooth_factor=True
).add_to(m)
for child in salud11._children:
    if child.startswith("color_map"):
        del salud11._children[child]
        
salud11.get_root().add_child(salud11.color_scale)
salud11.add_child(salud11_leg)

salud12=folium.Choropleth(
    geo_data=salud_gdf,
    data=salud_gdf,
    name='% de población de 20 años y más con diagnóstico previo de hipertensión.',
    columns=['CVEGEO', 'Porcentaje de población de 20 años y más con diagnóstico previo de hipertensión.'],
    key_on='feature.properties.CVEGEO',
    fill_color='YlGnBu',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='% de población de 20 años y más con diagnóstico previo de hipertensión.',
    show=False,
    control=True,
    highlight=True,
    smooth_factor=True
).add_to(m)
for child in salud12._children:
    if child.startswith("color_map"):
        del salud12._children[child]
        
salud12.get_root().add_child(salud12.color_scale)
salud12.add_child(salud12_leg)

salud13=folium.Choropleth(
    geo_data=salud_gdf,
    data=salud_gdf,
    name='Número de Camas',
    columns=['CVEGEO', 'Total general_Camas'],
    key_on='feature.properties.CVEGEO',
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Número de Camas',
    show=False,
    control=True,
    highlight=True,
    smooth_factor=True
).add_to(m)
for child in salud13._children:
    if child.startswith("color_map"):
        del salud13._children[child]
        
salud13.get_root().add_child(salud13.color_scale)
salud13.add_child(salud13_leg)

salud14=folium.Choropleth(
    geo_data=salud_gdf,
    data=salud_gdf,
    name='Número de Consultorios',
    columns=['CVEGEO', 'Total general_Consul'],
    key_on='feature.properties.CVEGEO',
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Número de Consultorios',
    show=False,
    control=True,
    highlight=True,
    smooth_factor=True
).add_to(m)
for child in salud14._children:
    if child.startswith("color_map"):
        del salud14._children[child]
        
salud14.get_root().add_child(salud14.color_scale)
salud14.add_child(salud14_leg)

salud15=folium.Choropleth(
    geo_data=salud_gdf,
    data=salud_gdf,
    name='Vacuna DTP (difteria, tosferina y tétanos)',
    columns=['CVEGEO', 'Vacuna DTP (difteria, tosferina y tétanos) '],
    key_on='feature.properties.CVEGEO',
    fill_color='BuGn',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Vacuna DTP difteria, tosferina y tétanos',
    show=False,
    control=True,
    highlight=True,
    smooth_factor=True
).add_to(m)
for child in salud15._children:
    if child.startswith("color_map"):
        del salud15._children[child]
        
salud15.get_root().add_child(salud15.color_scale)
salud15.add_child(salud15_leg)

salud16=folium.Choropleth(
    geo_data=salud_gdf,
    data=salud_gdf,
    name='Refuerzo DTP Difteria, tosferina y tétanos',
    columns=['CVEGEO', 'Refuerzo DTP (Difteria, tosferina y tétanos)'],
    key_on='feature.properties.CVEGEO',
    fill_color='BuGn',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Refuerzo DTP Difteria, tosferina y tétanos',
    show=False,
    control=True,
    highlight=True,
    smooth_factor=True
).add_to(m)
for child in salud16._children:
    if child.startswith("color_map"):
        del salud16._children[child]
        
salud16.get_root().add_child(salud16.color_scale)
salud16.add_child(salud16_leg)

salud17=folium.Choropleth(
    geo_data=salud_gdf,
    data=salud_gdf,
    name='Vacuna MCV (Antimeningócocica)',
    columns=['CVEGEO', 'Vacuna MCV (Antimeningócocica)'],
    key_on='feature.properties.CVEGEO',
    fill_color='BuGn',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Vacuna MCV (Antimeningócocica)',
    show=False,
    control=True,
    highlight=True,
    smooth_factor=True
).add_to(m)
for child in salud17._children:
    if child.startswith("color_map"):
        del salud17._children[child]
        
salud17.get_root().add_child(salud17.color_scale)
salud17.add_child(salud17_leg)

salud18=folium.Choropleth(
    geo_data=salud_gdf,
    data=salud_gdf,
    name='Refuerzo MCV (Antimeningócocica)',
    columns=['CVEGEO', 'Refuerzo MCV (Antimeningócocica)'],
    key_on='feature.properties.CVEGEO',
    fill_color='BuGn',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Refuerzo MCV (Antimeningócocica)',
    show=False,
    control=True,
    highlight=True,
    smooth_factor=True
).add_to(m)
for child in salud18._children:
    if child.startswith("color_map"):
        del salud18._children[child]
        
salud18.get_root().add_child(salud18.color_scale)
salud18.add_child(salud18_leg)

salud19=folium.Choropleth(
    geo_data=salud_gdf,
    data=salud_gdf,
    name='Vacuna POL (Poliomelitis)',
    columns=['CVEGEO', 'Vacuna POL (Poliomelitis)'],
    key_on='feature.properties.CVEGEO',
    fill_color='BuGn',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Vacuna POL (Poliomelitis)',
    show=False,
    control=True,
    highlight=True,
    smooth_factor=True
).add_to(m)
for child in salud19._children:
    if child.startswith("color_map"):
        del salud19._children[child]
        
salud19.get_root().add_child(salud19.color_scale)
salud19.add_child(salud19_leg)
#salud6.add_child(salud6_leg)

#disc_group = folium.FeatureGroup(name='Personas con discapacidad')
#subgroup = folium.FeatureGroup(name='Salud').add_to(m)

# Agregar capas al grupo dentro de FeatureGroupSubGroup

#disc_group.add_child(salud1)

#disc_group.add_to(m)


psd1.geojson.add_child(
    folium.features.GeoJsonTooltip(fields=["NOMGEO", "POR_PSD"],aliases=["Municipio: ","% Población sin derechohabiencia: "],  sticky=False, localize=True)
)
salud1.geojson.add_child(
    folium.features.GeoJsonTooltip(fields=["NOMGEO", "% Personas con discapacidad motriz"],aliases=["Municipio: ","% Personas con discapacidad motríz: "],  sticky=False, localize=True)
)
salud2.geojson.add_child(
    folium.features.GeoJsonTooltip(fields=["NOMGEO", "%Personas con alguna condición mental"],aliases=["Municipio: ","%Personas con alguna condición mental: "],  sticky=False, localize=True)
)
salud3.geojson.add_child(
    folium.features.GeoJsonTooltip(fields=["NOMGEO", "% Personas con discapacidad visual"],aliases=["Municipio: ","% Personas con discapacidad visual: "],  sticky=False, localize=True)
)
salud4.geojson.add_child(
    folium.features.GeoJsonTooltip(fields=["NOMGEO", "% Personas con discapacidad del habla"],aliases=["Municipio: ","% Personas con discapacidad del habla: "],  sticky=False, localize=True)
)
salud5.geojson.add_child(
    folium.features.GeoJsonTooltip(fields=["NOMGEO", "% Personas con discapacidad auditiva"],aliases=["Municipio: ","% Personas con discapacidad auditiva: "],  sticky=False, localize=True)
)
salud6.geojson.add_child(
    folium.features.GeoJsonTooltip(fields=["NOMGEO", "Casos de COVID atendidos durante el 2022"],aliases=["Municipio: ","Casos de COVID atendidos durante el 2022: "],  sticky=False, localize=True)
)
salud7.geojson.add_child(
    folium.features.GeoJsonTooltip(fields=["NOMGEO", "Casos activos de Dengue al 10/03/23"],aliases=["Municipio: ","%Casos activos de Dengue al 10/03/23: "],  sticky=False, localize=True)
)
salud8.geojson.add_child(
    folium.features.GeoJsonTooltip(fields=["NOMGEO", "tasa de mortalidad infantil"],aliases=["Municipio: ","tasa de mortalidad infantil: "],  sticky=False, localize=True)
)
salud9.geojson.add_child(
    folium.features.GeoJsonTooltip(fields=["NOMGEO", "Defunciones maternales 2021"],aliases=["Municipio: ","Defunciones maternales 2021: "],  sticky=False, localize=True)
)
salud10.geojson.add_child(
    folium.features.GeoJsonTooltip(fields=["NOMGEO", "defunciones infantiles 2021"],aliases=["Municipio: ","Defunciones infantiles 2021: "],  sticky=False, localize=True)
)
salud11.geojson.add_child(
    folium.features.GeoJsonTooltip(fields=["NOMGEO", "Porcentaje de población de 20 años y más con obesidad."],aliases=["Municipio: ","% de población de 20 años y más con obesidad: "],  sticky=False, localize=True)
)
salud12.geojson.add_child(
    folium.features.GeoJsonTooltip(fields=["NOMGEO", "Porcentaje de población de 20 años y más con diagnóstico previo de hipertensión."],aliases=["Municipio: ","% de población de 20 años y más con diagnóstico previo de hipertensión: "],  sticky=False, localize=True)
)
salud13.geojson.add_child(
    folium.features.GeoJsonTooltip(fields=["NOMGEO", "Total general_Camas"],aliases=["Municipio: ","Número de Camas: "],  sticky=False, localize=True)
)
salud15.geojson.add_child(
    folium.features.GeoJsonTooltip(fields=["NOMGEO", "Vacuna DTP (difteria, tosferina y tétanos) "],aliases=["Municipio: ","Vacunas DTP (difteria, tosferina y tétanos): "],  sticky=False, localize=True)
)
salud16.geojson.add_child(
    folium.features.GeoJsonTooltip(fields=["NOMGEO", "Refuerzo DTP (Difteria, tosferina y tétanos)"],aliases=["Municipio: ","Refuerzo DTP (Difteria, tosferina y tétanos): "],  sticky=False, localize=True)
)
salud14.geojson.add_child(
    folium.features.GeoJsonTooltip(fields=["NOMGEO", "Total general_Consul"],aliases=["Municipio: ","Número de Consultorios: "],  sticky=False, localize=True)
)
salud17.geojson.add_child(
    folium.features.GeoJsonTooltip(fields=["NOMGEO", "Vacuna MCV (Antimeningócocica)"],aliases=["Municipio: ","Vacunas MCV (Antimeningócocica): "],  sticky=False, localize=True)
)
salud18.geojson.add_child(
    folium.features.GeoJsonTooltip(fields=["NOMGEO", "Refuerzo MCV (Antimeningócocica)"],aliases=["Municipio: ","Refuerzo MCV (Antimeningócocica): "],  sticky=False, localize=True)
)
salud19.geojson.add_child(
    folium.features.GeoJsonTooltip(fields=["NOMGEO", "Vacuna POL (Poliomelitis)"],aliases=["Municipio: ","Vacuna POL (Poliomelitis): "],  sticky=False, localize=True)
)

#Control de localización del usuario
'''lc = LocateControl(locatingMsg='Espera mientras se encuentra tu ubicación',
                   locate_options={'enableHighAccuracy': True, 'watch':True},
                   strings={"title": "Encuentra tu ubicación", "popup": "Te encuentras cerca de aquí"}).add_to(m)'''
buscador= Search(
    layer=psdh,
    geom_type='Polygon',
    position='topleft',
    placeholder='Busqueda por municipio...',
    collapsed=False,
    search_zoom='13',
    search_label='NOMGEO'
).add_to(m)

#m.add_child(folium.LatLngPopup())


folium.LayerControl(collapsed=False, position="topright", title="Capas").add_to(m)
plugins.MeasureControl(position='toright').add_to(m)
plugins.Fullscreen(position='bottomleft').add_to(m)
minimap = plugins.MiniMap()
m.add_child(minimap)
#m
m.save('visor_salud1.html')

# %%
# Out:
# 0.14.0

# %%
# Out:
# 0.14.0

# %%
# Out:
# 0.14.0
